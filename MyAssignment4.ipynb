# %%
import matplotlib.pyplot as plt

# %%
sub = ["Porgramming Fundamentals",'ICT','Islamic Studies','Basic Electronics','Calculus']
marks = [50,25,56,64,55]

# %%
plt.pie(marks,labels = sub,autopct = '%1.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7f13d9f8d400>,
# ...
#  [Text(0.8899186877588753, 0.6465637858537406, 'Porgramming Fundamentals'),
#   Text(-2.5747358111484753e-08, 1.0999999999999999, 'ICT'),
#   Text(-0.9360939587486764, 0.5776920463311154, 'Islamic Studies'),
#   Text(-0.6353298752293922, -0.89797324550401, 'Basic Electronics'),
#   Text(0.847564668151179, -0.7011662665172804, 'Calculus')],
#  [Text(0.4854101933230228, 0.35267115592022213, '20.00%'),
#   Text(-1.4044013515355319e-08, 0.5999999999999999, '10.00%'),
#   Text(-0.5105967047720052, 0.31510475254424475, '22.40%'),
#   Text(-0.34654356830694116, -0.48980358845673266, '25.60%'),
#   Text(0.46230800080973394, -0.38245432719124384, '22.00%')])
